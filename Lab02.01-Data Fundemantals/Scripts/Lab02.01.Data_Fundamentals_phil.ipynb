# %% [markdown]
# # Data Fundamentals for Research
#
# Welcome! This session will teach you essential data analysis skills for academic research. No prior data science experience required.
#
# ## What You'll Learn
# By the end of this 2-hour session, you'll be able to:
# - Load and explore research datasets
# - Filter and select specific information
# - Clean and prepare data for analysis
# - Create visualizations and extract insights
#
# ## How This Works
# Each topic follows a simple pattern:
# 1. **Demonstrate** - I'll show you one key concept
# 2. **Practice** - You'll complete 3 guided tasks that build on each other
# 3. **Hints** - Available after each task if you need help
# 4. **Summary** - Key concepts and explanations
#
# ## Dataset
# We'll work with a philosophy papers dataset containing titles, summaries, and philosophical school classifications.
#
# Ready? Let's start!

# %%
# Import all necessary libraries
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Mathematical operations
import matplotlib.pyplot as plt  # Data visualization
from collections import Counter  # Counting unique elements
import ast  # Abstract Syntax Trees

print("✅ All libraries imported successfully!")

# %% [markdown]
# ---
#
# ## Part 1: Data Loading and First Look
#
# **Goal**: Get comfortable with datasets and understand structure

# %%
# Demonstrate: Load CSV and examine first rows
print("📥 Loading data with pd.read_csv()...")

# Load the dataset
df = pd.read_csv("philpapers_enhanced_clean.csv")

# Look at first few rows
print("\n🔍 First 5 rows of data:")
df.head()

# %% [markdown]
# ### 🎯 Practice Tasks:

# %%
# Task 1: Discover the dataset dimensions
# Use df.shape to find how many papers and features we have
# Expected output: "Dataset contains X papers with Y features"
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 1</summary>
#
# ```python
# # Get dataset dimensions
# rows, cols = df.shape
# print(f"Dataset contains {rows} papers with {cols} features")
# ```
# </details>

# %%
# Task 2: Identify which columns have missing data
# Check for missing values and show only columns that have them
# Expected output: List of columns with missing values and their counts
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 2</summary>
#
# ```python
# # Check missing values
# missing = df.isnull().sum()
# missing_cols = missing[missing > 0]
#
# if len(missing_cols) > 0:
#     print("Columns with missing values:")
#     print(missing_cols)
# else:
#     print("No missing values found!")
# ```
# </details>

# %%
# Task 3: Profile the text columns
# Find which columns contain text vs numbers, focus on title and summary lengths
# Expected output: Data types and average length of title and summary
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 3</summary>
#
# ```python
# # Check data types
# print("Data types:")
# print(df.dtypes)
#
# # Calculate average lengths
# print(f"\nAverage title length: {df['title_length'].mean():.0f} characters")
# print(f"Average summary length: {df['summary_length'].mean():.0f} characters")
# ```
# </details>

# %%
# 🌟 Bonus: Find the longest and shortest paper titles
# Display the actual titles, not just their lengths
# Write your code here:

# %% [markdown]
# **Summary - Part 1:**
# - `pd.read_csv()`: Loads CSV files into a DataFrame
# - `df.head()`: Shows first 5 rows by default
# - `df.shape`: Returns (rows, columns)
# - `df.isnull().sum()`: Counts missing values per column
# - `df.dtypes`: Shows data type of each column

# %% [markdown]
# ---
#
# ## Part 2: Data Selection & Filtering
#
# **Goal**: Find and extract specific information from data

# %%
# Demonstrate: Filter data with conditions
print("🔍 Filtering data with df[condition]...")

# Filter papers with title length > 100
long_titles = df[df['title_length'] > 100]
print(f"\nFound {len(long_titles)} papers with long titles")
print("\nExample:")
long_titles.head(2)

# %% [markdown]
# ### 🎯 Practice Tasks:

# %%
# Task 1: Find all papers about consciousness (or any other concept)
# Use .str.contains() to search titles
# Expected output: Number of papers found and first 3 titles
# Save result as 'consciousness_papers' for later use
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 1</summary>
#
# ```python
# # Find papers about consciousness
# consciousness_papers = df[df['title'].str.contains('consciousness', case=False, na=False)]
# print(f"Found {len(consciousness_papers)} papers about consciousness")
# print("\nFirst 3 titles:")
# for i, title in enumerate(consciousness_papers['title'].head(3)):
#     print(f"{i+1}. {title}")
# ```
# </details>

# %%
# Task 2: Find consciousness papers with substantial summaries (or any other concept)
# Filter consciousness_papers to only those with summary_length > 500
# Expected output: Number of detailed consciousness papers
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 2</summary>
#
# ```python
# # Filter for detailed papers
# detailed_consciousness = consciousness_papers[consciousness_papers['summary_length'] > 500]
# print(f"Found {len(detailed_consciousness)} consciousness papers with detailed summaries")
# print(f"This is {len(detailed_consciousness)/len(consciousness_papers)*100:.1f}% of all consciousness papers")
# ```
# </details>

# %%
# Task 3: Create a focused dataset for consciousness research (or any other concept)
# Select only title, summary, and philosophy_schools columns from consciousness_papers
# Expected output: Shape of new dataset and preview
# Save as 'consciousness_subset' for Part 3
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 3</summary>
#
# ```python
# # Create focused dataset
# consciousness_subset = consciousness_papers[['title', 'summary', 'philosophy_schools']]
# print(f"Consciousness research dataset: {consciousness_subset.shape}")
# print("\nPreview:")
# consciousness_subset.head(3)
# ```
# </details>

# %%
# 🌟 Bonus: Find papers that mention BOTH consciousness AND mind (or any other two concepts)
# How many papers discuss both concepts?
# Write your code here:

# %% [markdown]
# **Summary - Part 2:**
# - `df[condition]`: Filters rows based on boolean conditions
# - `.str.contains()`: Searches for text patterns
# - Compound conditions: `df[(condition1) & (condition2)]`
# - `df[['col1', 'col2']]`: Selects specific columns
# - Building focused datasets for specific research questions

# %% [markdown]
# ---
#
# ## Part 3: Data Cleaning & Feature Engineering
#
# **Goal**: Prepare data for analysis by creating new features

# %%
# Demonstrate: Inspect missing data
print("🔍 Inspecting missing values with .isnull().sum()...")

# Check missing values
missing = df.isnull().sum()
print("\nMissing values per column:")
print(missing[missing > 0])

# %% [markdown]
# ### 🎯 Practice Tasks:

# %%
# Task 1: Add question detection to consciousness_subset
# Create 'is_question' column for titles containing '?'
# Expected output: Number and percentage of questions
# Work with consciousness_subset from Part 2
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 1</summary>
#
# ```python
# # Add question detection
# consciousness_subset = consciousness_subset.copy()
# consciousness_subset['is_question'] = consciousness_subset['title'].str.contains('?', regex=False)
#
# # Calculate statistics
# num_questions = consciousness_subset['is_question'].sum()
# pct_questions = num_questions / len(consciousness_subset) * 100
# print(f"Questions: {num_questions} ({pct_questions:.1f}%)")
# print("\nExample questions:")
# print(consciousness_subset[consciousness_subset['is_question']]['title'].head(3).tolist())
# ```
# </details>

# %%
# Task 2: Parse philosophical schools and count them
# Convert philosophy_schools string to list and count schools per paper
# Expected output: Average schools per consciousness paper
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 2</summary>
#
# ```python
# # Parse philosophy schools
# consciousness_subset['school_list'] = consciousness_subset['philosophy_schools'].apply(ast.literal_eval)
# consciousness_subset['num_schools'] = consciousness_subset['school_list'].str.len()
#
# # Analyze
# avg_schools = consciousness_subset['num_schools'].mean()
# print(f"Average philosophical schools per consciousness paper: {avg_schools:.2f}")
# print(f"Range: {consciousness_subset['num_schools'].min()} to {consciousness_subset['num_schools'].max()} schools")
# ```
# </details>

# %%
# Task 3: Categorize papers by depth
# Create categories based on summary length: Brief (<300), Standard (300-600), Detailed (>600)
# Expected output: Distribution of consciousness papers by depth
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 3</summary>
#
# ```python
# # Get summary lengths from original data
# consciousness_subset['summary_length'] = df.loc[consciousness_subset.index, 'summary_length']
#
# # Create research depth categories
# consciousness_subset['summary_depth'] = pd.cut(
#     consciousness_subset['summary_length'],
#     bins=[0, 300, 600, 10000],
#     labels=['Brief', 'Standard', 'Detailed']
# )
#
# # Show distribution
# depth_counts = consciousness_subset['summary_depth'].value_counts()
# print("Research depth distribution:")
# for depth, count in depth_counts.items():
#     print(f"  {depth}: {count} papers ({count/len(consciousness_subset)*100:.1f}%)")
# ```
# </details>

# %%
# 🌟 Bonus: Which philosophical schools most commonly study consciousness?
# Extract and count all schools from consciousness papers
# Write your code here:

# %% [markdown]
# **Summary - Part 3:**
# - `.isnull().sum()`: Counts missing values
# - `.str.contains()`: Creates boolean columns
# - `ast.literal_eval()`: Parses string representations of lists
# - `pd.cut()`: Creates categorical bins from numeric data
# - Feature engineering helps answer specific research questions

# %% [markdown]
# ---
#
# ## Part 4: Visualization & Insights
#
# **Goal**: Answer research questions and present findings

# %%
# Demonstrate: Group data
print("📊 Grouping data with .groupby()...")

# Group by research depth and analyze
grouped = consciousness_subset.groupby('summary_depth')['num_schools'].mean()
print("\nAverage philosophical schools by research depth:")
print(grouped.round(2))

# %% [markdown]
# ### 🎯 Practice Tasks:

# %%
# Task 1: Compare question vs statement papers
# Calculate average number of schools for questions vs statements
# Expected output: Which type engages with more philosophical traditions?
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 1</summary>
#
# ```python
# # Compare questions vs statements
# question_analysis = consciousness_subset.groupby('is_question')['num_schools'].agg(['mean', 'count'])
# question_analysis.index = ['Statements', 'Questions']
#
# print("Philosophical engagement by paper type:")
# print(question_analysis.round(2))
# print(f"\nQuestions engage with {question_analysis.loc['Questions', 'mean'] - question_analysis.loc['Statements', 'mean']:.1f} more schools on average")
# ```
# </details>

# %%
# Task 2: Identify the most interdisciplinary papers
# Find top 5 papers with most philosophical schools
# Expected output: Titles and school counts of most interdisciplinary papers
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 2</summary>
#
# ```python
# # Find most interdisciplinary papers
# top_interdisciplinary = consciousness_subset.nlargest(5, 'num_schools')[['title', 'num_schools', 'school_list']]
#
# print("Most interdisciplinary consciousness papers:")
# for idx, row in top_interdisciplinary.iterrows():
#     print(f"\n{row['num_schools']} schools: {row['title'][:80]}...")
#     print(f"   Schools: {', '.join(row['school_list'][:3])}...")
# ```
# </details>

# %%
# Task 3: Visualize summary depth distribution
# Create a bar chart showing consciousness papers by summary depth
# Expected output: Bar chart with counts and percentages
# Write your code here:

# %% [markdown]
# <details>
# <summary>💡 Hint for Task 3</summary>
#
# ```python
# # Create visualization
# plt.figure(figsize=(8, 6))
# depth_counts = consciousness_subset['summary_depth'].value_counts()
#
# # Create bar chart
# bars = plt.bar(depth_counts.index, depth_counts.values,
#                 color=['lightcoral', 'skyblue', 'lightgreen'])
#
# # Add value labels on bars
# for bar, count in zip(bars, depth_counts.values):
#     height = bar.get_height()
#     plt.text(bar.get_x() + bar.get_width()/2., height,
#              f'{count}\n({count/len(consciousness_subset)*100:.0f}%)',
#              ha='center', va='bottom')
#
# plt.title('Consciousness Papers by Research Depth', fontsize=14)
# plt.xlabel('Research Depth')
# plt.ylabel('Number of Papers')
# plt.grid(axis='y', alpha=0.3)
# plt.show()
# ```
# </details>

# %%
# 🌟 Bonus: Create a summary report of consciousness research
# Combine all your findings into a brief statistical summary
# Write your code here:

# %% [markdown]
# **Summary - Part 4:**
# - `.groupby()`: Groups data by categories for analysis
# - `.agg()`: Applies multiple functions to grouped data
# - `.nlargest()`: Finds top N rows by a column value
# - `plt.bar()`: Creates bar charts
# - Combining multiple analyses to answer complex research questions

# %% [markdown]
# ---
#
# ## What We've Done So Far
#
# 1. **Loaded** a philosophy papers dataset and understood its structure
# 2. **Filtered** to consciousness papers - a focused research area
# 3. **Enhanced** the data with question detection and depth categories
# 4. **Discovered** that question-based papers engage with more philosophical schools
#
# ## Core Skills Covered:
# - **Data Loading**: Import and explore research datasets
# - **Targeted Filtering**: Extract papers on specific topics
# - **Feature Engineering**: Create meaningful categories for analysis
# - **Insights**: Compare groups and find patterns
# - **Data Visualization**: Communicate findings effectively
#
# ### Next Steps:
# - Try this workflow with different philosophical topics (ethics, epistemology, metaphysics)

# %% [markdown]
# ## Authors:
#
# [Yunus Emre Tapan](https://www.linkedin.com/in/yunus-emre-tapan/)
#
# [Aniket Ghosh](https://www.linkedin.com/in/aniketghosh-/)
